# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,6*np.pi)
a=1
plt .plot(x,np.sin(x),x,np.cos(x))
# Out:
# [<matplotlib.lines.Line2D at 0x25ded54e5b0>,
#  <matplotlib.lines.Line2D at 0x25ded54e610>]

# %%
n=0
for i in range(1,5):
    for j in range(1,5):
        for k in range(1,5):
            if(i !=k ) and (i !=j) and (j !=k):
                n=n+1
                print (i,j,k "n=",n)
# Out:
#   File "C:\Users\22162\AppData\Local\Temp\ipykernel_14868\101645581.py", line 7
#     print (i,j,k "n=",n)
#                  ^
# SyntaxError: invalid syntax

# %%
L=[]
a=[1,2,3,4]

#for 1 in range(len(a)):

for val_1 in a:   #   for(i=1;i<n;I++)
    for val_2 in a:
        for val_3 in a:
            if(val_1 == val_2 or val_1==val_3 or val_2 ==val_3):
                continue;
            else:
                L:append(str(val_1)+str(val_2)+str(val_3))


print(len(L))
print (L)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14868\1268490887.py in <module>
# ----> 1 L-[]
#       2 a=[1,2,3,4]
#       3
#       4 #for 1 in range(len(a)):
#       5
#
# NameError: name 'L' is not defined

# %%
profit =0
I = int(input("please input: "))
if(I<=10):
    profit = 0.1 *I
elif(I<=20):
    profit = 10*0.1+ (I-10)*0.075
elif(I<=40):
    profit = 10*0.1+ (20-10)*0.075+(I-20)*0.05
elif(I<=60):
    profit = 10*0.1+ (20-10)*0.075+(40-20)*0.05+(I-40)*0.03
elif(I<=80):
    profit = 10*0.1+ (20-10)*0.075+(40-20)*0.05+(60-40)*0.03
